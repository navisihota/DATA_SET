# %% [markdown]
# <a href="https://colab.research.google.com/github/navisihota/DATA_SET/blob/main/Assignment_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
A_data = pd.read_csv('https://github.com/sukhioo7/pandas_data/blob/main/Salaries.csv?raw=True')
A_data.head()
# Out:
# <ipython-input-20-d2c31c675831>:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   A_data = pd.read_csv('https://github.com/sukhioo7/pandas_data/blob/main/Salaries.csv?raw=True')
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# ...

# %%
A_data.eq('Not provided').any(axis=1)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650     True
# 148651     True
# 148652     True
# 148653    False
# Length: 148654, dtype: bool

# %%
A_data[A_data.eq('Not Provided').any(axis=1)]
# Out:
#             Id  EmployeeName                                 JobTitle  \
# 13797    13798  Not Provided  PUBLIC SAFETY COMMUNICATIONS DISPATCHER
# 44151    44152  Not Provided                   Public SafetyComm Disp
# 148646  148647  Not provided                             Not provided
# 148650  148651  Not provided                             Not provided
# 148651  148652  Not provided                             Not provided
# 148652  148653  Not provided                             Not provided
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# 13797       57963.39      19683.91       4373.86           NaN   82021.16
# 44151       82196.52       25934.2       3752.49       38024.3  111883.21
# 148646  Not Provided  Not Provided  Not Provided  Not Provided       0.00
# 148650  Not Provided  Not Provided  Not Provided  Not Provided       0.00
# 148651  Not Provided  Not Provided  Not Provided  Not Provided       0.00
# ...

# %%
A_data = A_data.replace('Not Provided',np.nan)

# %%
A_data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             2
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
A_data.drop(["Notes","Status"],axis=1,inplace=True)

# %%
a =A_data['Benefits'].median()
a
# Out:
# 28628.62

# %%
A_data['Benefits']=A_data['Benefits'].fillna(value=a)

# %%
A_data.dropna(inplace=True)

# %%
A_data.reset_index(drop=True,inplace=True)

# %%
A_data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148038  148646   Carolyn A Wilson
# 148039  148648     Joann Anderson
# 148040  148649        Leon Walker
# 148041  148650      Roy I Tillery
# 148042  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %%
A_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148043 entries, 0 to 148042
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148043 non-null  int64
#  1   EmployeeName      148043 non-null  object
#  2   JobTitle          148043 non-null  object
#  3   BasePay           148043 non-null  object
#  4   OvertimePay       148043 non-null  object
#  5   OtherPay          148043 non-null  object
#  6   Benefits          148043 non-null  object
#  7   TotalPay          148043 non-null  float64
#  8   TotalPayBenefits  148043 non-null  float64
#  9   Year              148043 non-null  int64
#  10  Agency            148043 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 12.4+ MB

# %%
A_data['BasePay']=A_data['BasePay'].astype('float')

# %%
A_data['OvertimePay']=A_data['OvertimePay'].astype('float')

# %%
A_data['OtherPay']=A_data['OtherPay'].astype('float')

# %%
A_data['Benefits']=A_data['Benefits'].astype('float')

# %%
A_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148043 entries, 0 to 148042
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148043 non-null  int64
#  1   EmployeeName      148043 non-null  object
#  2   JobTitle          148043 non-null  object
#  3   BasePay           148043 non-null  float64
#  4   OvertimePay       148043 non-null  float64
#  5   OtherPay          148043 non-null  float64
#  6   Benefits          148043 non-null  float64
#  7   TotalPay          148043 non-null  float64
#  8   TotalPayBenefits  148043 non-null  float64
#  9   Year              148043 non-null  int64
#  10  Agency            148043 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 12.4+ MB

# %% [markdown]
# 1) Show the first five rows of the dataset

# %%
A_data.head(5)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25  28628.62  567595.43         567595.43
# 1  155966.02    245131.88  137811.38  28628.62  538909.28         538909.28
# 2  212739.13    106088.18   16452.60  28628.62  335279.91         335279.91
# 3   77916.00     56120.71  198306.90  28628.62  332343.61         332343.61
# 4  134401.60      9737.00  182234.59  28628.62  326373.19         326373.19
#
#    Year         Agency
# 0  2011  San Francisco
# ...

# %% [markdown]
# 2) Calculate the average of BasePay series

# %%
A_data['BasePay'].mean()
# Out:
# 66325.3981186547

# %% [markdown]
# 3) What is the highest amount of OvertimePay and OtherPay

# %%
O=A_data['OvertimePay'].max()
o=A_data['OvertimePay'].max()
print(O)
print(o)
# Out:
# 245131.88
# 245131.88

# %% [markdown]
# 4) What is the name of lowest paid person including Benefits

# %%
a=A_data['TotalPayBenefits'].min()
A_data[A_data.eq(a).any(axis=1)]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148042  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year         Agency
# 148042   -618.13       0.0   -618.13           -618.13  2014  San Francisco

# %% [markdown]
# 5) What is the average BasePay of all employee per year(2011-2014)

# %%
A_data[A_data['Year']<=2011]
year_11=A_data['BasePay'][A_data['Year']==2011].mean()
year_12=A_data['BasePay'][A_data['Year']==2012].mean()
year_13=A_data['BasePay'][A_data['Year']==2013].mean()
year_14=A_data['BasePay'][A_data['Year']==2014].mean()
print(year_11)
print(year_12)
print(year_13)
print(year_14)
# Out:
# 63596.11229326844
# 65435.95098599212
# 69630.03021648063
# 66564.42192449959

# %% [markdown]
# 6) How many people have Chief word in their JobTitle (optional

# %%
A_data[A_data['JobTitle'].str.contains('chief', case=False)]
# Out:
#             Id         EmployeeName  \
# 4            5      PATRICK GARDNER
# 5            6       DAVID SULLIVAN
# 6            7            ALSON LEE
# 8            9       MICHAEL MORRIS
# 9           10   JOANNE HAYES-WHITE
# ...        ...                  ...
# 137404  138012     Sharon C Jackson
# 139013  139621          Anita S Lee
# 139102  139710     George D Vaughan
# 139473  140081  Patrick W Gillespie
# 139549  140157  Christopher L Ochoa
#
#                                             JobTitle    BasePay  OvertimePay  \
# 4       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# 5                          ASSISTANT DEPUTY CHIEF II  118602.00      8601.00
# 6                 BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01     89062.90
# 8                 BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64     86362.68
# 9             CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00         0.00
# ...

# %% [markdown]
# 7) What are top 5 most common jobs?

# %%
A_data['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                6975
# Special Nurse                   4382
# Registered Nurse                3725
# Public Svc Aide-Public Works    2514
# Police Officer 3                2411
# Name: JobTitle, dtype: int64

# %% [markdown]
# 8) How many unique job titles are there?

# %%
 A_data['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ...,
#        'Forensic Toxicologist Supervis', 'Conversion', 'Cashier 3'],
#       dtype=object)

# %% [markdown]
# 9) Show last five rows of the dataset?

# %%
A_data.tail(5)
# Out:
#             Id      EmployeeName                     JobTitle  BasePay  \
# 148038  148646  Carolyn A Wilson    Human Services Technician      0.0
# 148039  148648    Joann Anderson  Communications Dispatcher 2      0.0
# 148040  148649       Leon Walker                    Custodian      0.0
# 148041  148650     Roy I Tillery                    Custodian      0.0
# 148042  148654         Joe Lopez   Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148038          0.0      0.00       0.0      0.00              0.00  2014
# 148039          0.0      0.00       0.0      0.00              0.00  2014
# 148040          0.0      0.00       0.0      0.00              0.00  2014
# 148041          0.0      0.00       0.0      0.00              0.00  2014
# 148042          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#                Agency
# 148038  San Francisco
# 148039  San Francisco
# 148040  San Francisco
# ...

# %% [markdown]
# 10) How many job titles were represented by only one person in 2013? (example : JobTitles with only one occurence in 2013) (optional)

# %%
a=A_data[A_data['Year']==2013]
b=a['JobTitle'].value_counts()
(b==1).sum()
# Out:
# 202
